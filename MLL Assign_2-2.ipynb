# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import seaborn as sns
#       5 from sklearn.model_selection import train_test_split
#       6 from pandas.core.common import random_state
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import pandas as pd
df_sal = pd.read_csv('Salary_Data.csv')
df_sal.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df_sal.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
plt.scatter(df_sal['YearsExperience'], df_sal['Salary'], color = 'lightcoral')
plt.title('Salary vs Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.box(False)
plt.show()

# %%
X = df_sal.iloc[:, :1] 
y = df_sal.iloc[:, 1:]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 regressor = LinearRegression()
#       2 regressor.fit(X_train, y_train)
#
# NameError: name 'LinearRegression' is not defined

# %%
y_pred_test = regressor.predict(X_test)     # predicted value of y_test
y_pred_train = regressor.predict(X_train)

# %%
#training set
plt.scatter(X_train, y_train, color = 'lightcoral')
plt.plot(X_train, y_pred_train, color = 'firebrick')
plt.title('Salary vs Experience (Training Set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend(['X_train/Pred(y_test)', 'X_train/y_train'], title = 'Sal/Exp', loc='best', facecolor='white')
plt.box(False)
plt.show()

# %%
# Prediction on test set
plt.scatter(X_test, y_test, color = 'lightcoral')
plt.plot(X_train, y_pred_train, color = 'firebrick')
plt.title('Salary vs Experience (Test Set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend(['X_train/Pred(y_test)', 'X_train/y_train'], title = 'Sal/Exp', loc='best', facecolor='white')
plt.box(False)
plt.show()

# %%
print(f'Coefficient: {regressor.coef_}') #
print(f'Intercept: {regressor.intercept_}')
# Out:
# Coefficient: [[9312.57512673]]
# Intercept: [26780.09915063]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv('Salary_Data.csv')

# Extract variables
X_test = df[['YearsExperience']]
y_test = df[['Salary']]

slope = 9312.57512673         # regressor.coef_[0][0]
intercept = 26777.3913411976  # regressor.intercept_[0]

# Predict using y = mx + c
y_pred = slope * X_test['YearsExperience'] + intercept

# Compute residuals
residuals = y_test['Salary'] - y_pred

# Plot residuals
plt.figure(figsize=(8,5))
plt.scatter(X_test['YearsExperience'], residuals, color='darkorange')
plt.axhline(0, color='black', linestyle='--')
plt.title('Residual Plot: Salary vs Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Residual (Actual - Predicted)')
plt.grid(True)
plt.show()

# %%
import pandas as pd

df = pd.read_csv('Salary_Data.csv')

slope = 9312.57512673
intercept = 26777.3913411976

df['Predicted_Salary'] = slope * df['YearsExperience'] + intercept

df['Residual'] = df['Salary'] - df['Predicted_Salary']

print(df[['YearsExperience', 'Salary', 'Predicted_Salary', 'Residual']])
# Out:
#     YearsExperience    Salary  Predicted_Salary      Residual
# 0               1.1   39343.0      37021.223981   2321.776019
# 1               1.3   46205.0      38883.739006   7321.260994
# 2               1.5   37731.0      40746.254031  -3015.254031
# 3               2.0   43525.0      45402.541595  -1877.541595
# 4               2.2   39891.0      47265.056620  -7374.056620
# 5               2.9   56642.0      53783.859209   2858.140791
# 6               3.0   60150.0      54715.116721   5434.883279
# 7               3.2   54445.0      56577.631747  -2132.631747
# 8               3.2   64445.0      56577.631747   7867.368253
# 9               3.7   57189.0      61233.919310  -4044.919310
# 10              3.9   63218.0      63096.434335    121.565665
# 11              4.0   55794.0      64027.691848  -8233.691848
# 12              4.0   56957.0      64027.691848  -7070.691848
# 13              4.1   57081.0      64958.949361  -7877.949361
# ...

# %%
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

df = pd.read_csv('Salary_Data.csv')


slope = 9312.57512673
intercept = 26777.3913411976


df['Predicted_Salary'] = slope * df['YearsExperience'] + intercept


y_true = df['Salary']
y_pred = df['Predicted_Salary']

mse = mean_squared_error(y_true, y_pred)
mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_true, y_pred)

print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'Mean Absolute Error (MAE): {mae:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')
print(f'R² Score: {r2:.4f}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
#       3 import numpy as np
#       5 df = pd.read_csv('Salary_Data.csv')
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# !pip install scikit-learn
# Out:
# zsh:1: command not found: pip
